# %% [markdown]
# ![Python%20Excel%20Automation.png](attachment:Python%20Excel%20Automation.png)

# %% [markdown]
# ## การทำงานกับข้อมูลตารางกับ Python

# %% [markdown]
# ในการทำงานกับข้อมูลอย่าง Excel, csv เราจะใช้ library ที่ชื่อว่า pandas ซึ่งเป็นเครื่องมือที่นิยมใช้ในการวิเคราะห์ จัดการข้อมูลแบบตาราง ที่มาพร้อมกับเครื่องมือในการคำนวน การจัดการข้อมูลที่ใช้งานได้หลากหลายมากที่สุดอันหนึ่ง

# %% [markdown]
# ## ติดตั้ง pandas

# %% [markdown]
# จริงๆ แล้ว pandas เป็น library หรือชุดคำสั่งที่ต้องดาวน์โหลด และติดตั้งก่อนใช้งาน แต่ในบางกรณีเช่น การติดตั้งโปรแกรมอย่าง [Anaconda](https://www.anaconda.com/products/individual) จะมีการติดตั้ง pandas มาให้ด้วยแล้ว

# %% [markdown]
# สำหรับการติดตั้ง pandas เราจะใช้ pip ซึ่งเป็นโปรแกรมที่จัดการ package หรือชุดคำสั่งให้กับเรา ตามด้วยคำสั่ง install ตามด้วยชื่อ library นั่นคือ pandas นั่นเอง ซึ่งการติดตั้งเครื่องมือบนโปรแกรมบนเครื่องคอมพิวเตอร์ของเราต้องทำเพียงครั้งเดียวเท่านั้น แต่สำหรับการติดตั้งโปรแกรมออนไลน์จะต้องติดตั้งใหม่ทุกครั้งที่ใช้งาน

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\acer\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: pytz>=2017.2 in c:\users\acer\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\acer\anaconda3\lib\site-packages (from pandas) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %% [markdown]
# ## [เรียนรู้เกี่ยวกับ pandas บน official site](https://pandas.pydata.org/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ติดตั้ง openpyxl

# %% [markdown]
# openpyxl เป็น library ที่ใช้เพื่อการทำความเข้าใจข้อมูลใน Excel และ csv ซึ่งในกรณีที่ใช้โปรแกรม Anaconda และ Jupyter Notebook ที่ติดตั้งอยู่บนคอมพิวเตอร์ จะไม่จำเป็นต้องใช้ openpyxl ในการใช้ร่วมกับ pandas ในการเปิดไฟล์ เนื่องจากในโปรแกรมดังกล่าวมีการติดตั้งชุดคำสั่งที่ทำหน้าที่เปิดไฟล์ Excel มาให้แล้วนั่นเอง

# %% [markdown]
# แต่สำหรับการเปิดไฟล์ Excel ด้วย library pandas บนโปรแกรมออนไลน์ จะต้องติดตั้ง openpyxl เพื่อใช้ในการเปิดไฟล์ Excel ซึ่งการติดตั้งเครื่องมือบนโปรแกรมบนเครื่องคอมพิวเตอร์ของเราต้องทำเพียงครั้งเดียวเท่านั้น แต่สำหรับการติดตั้งโปรแกรมออนไลน์จะต้องติดตั้งใหม่ทุกครั้งที่ใช้งาน

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\acer\anaconda3\lib\site-packages (1.0.5)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\acer\anaconda3\lib\site-packages (from pandas) (1.17.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\acer\anaconda3\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\acer\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %% [markdown]
# ## [เรียนรู้เกี่ยวกับ Openpyxl บน Real Python](https://realpython.com/openpyxl-excel-spreadsheets-python/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## นำ pandas มาใช้

# %% [markdown]
# เมื่อทำการติดตั้งเรียบร้อยจะต้องนำชุดคำสั่งมาใช้งานบนไฟล์ Notebook ปัจจุบันที่เรากำลังเปิดใช้งานเพื่อเขียนโค้ดอยู่ ผ่านคำสั่ง import ซึ่งจะต้องทำทุกครั้งในการเปิดใช้งานไฟล์ Notebook

# %% [markdown]
# ซึ่งการใช้งาน library จะต้องเรียกใช้ตัว library ซ้ำๆ ดังนั้นเราสามารถตั้งชื่อเล่นให้กับ library ด้วยคำสั่ง as เพื่อตั้งชื่อเล่นให้สามารถเรียกใช้งานได้ง่ายขึ้น

# %%
import pandas as pd

# %% [markdown]
# ## ระบุไฟล์ที่ต้องการเปิด

# %% [markdown]
# จะขอแบ่งการระบุไฟล์เป็น 2 กรณี คือ การใช้งานโปรแกรมที่ติดตั้งบนคอมพิวเตอร์ และการใช้งานโปรแกรมออนไลน์

# %% [markdown]
# ### การใช้งานบนโปรแกรมที่ติดตั้งบนคอมพิวเตอร์

# %% [markdown]
# การระบุไฟล์ที่ต้องการสำหรับการใช้งานโปรแกรมที่ติดตั้งบนคอมพิวเตอร์สามารถทำได้ 2 วิธี

# %% [markdown]
# ### • การใช้ที่อยู่ของไฟล์

# %% [markdown]
# ผ่านการระบุตำแหน่งที่อยู่ของไฟล์บนคอมพิวเตอร์ด้วย path file แบบเต็มจนถึงตัวไฟล์ดังตัวอย่าง

# %% [markdown]
# #### ตัวอย่าง path file ใน windows

# %% [markdown]
# สำหรับการระบุ path ไฟล์ใน windows จะมีการใช้สัญลักษณ์ \ ซึ่งมีความหมายพิเศษในการทำงานกับ python เพื่อลบความหมายที่ซ่อนอยู่ออกจะต้องใส่ r เข้าไปด้านหน้า '' เพื่อเปลี่ยน string ที่ระบุไว้เป็น raw string ที่จะไม่มีการตีค่าเครื่องหมาย \

# %%
path_name = r"C:\Users\acer\Desktop\Excel Automation\North.xlsx"
path_name
# Out:
# 'C:\\Users\\acer\\Desktop\\Excel Automation\\North.xlsx'

# %% [markdown]
# #### ตัวอย่าง path file ใน mac

# %% [markdown]
# path ไฟล์ใน mac ใช้สัญลักษณ์ / ซึ่งไม่มีผลต่อการทำงานของ python ดังนั้นไม่จำเป็นต้องเปลี่ยนแปลงอะไร

# %%
path_name = "/Users/acer/Desktop/Excel Automation/North.xlsx"
path_name
# Out:
# '/Users/acer/Desktop/Excel Automation/North.xlsx'

# %% [markdown]
# ### • ระบุชื่อไฟล์

# %% [markdown]
# การระบุชื่อไฟล์ที่ต้องการเปิดสามารถทำได้ หากไฟล์ที่ต้องการเปิดอยู่ในโฟลเดอร์เดียวกันกับไฟล์ Notebook ที่กำลังเปิดใช้ในปัจจุบัน เท่านั้น!

# %%
name = "North.xlsx"
name
# Out:
# 'North.xlsx'

# %% [markdown]
# ## การระบุไฟล์ในโปรแกรมออนไลน์

# %% [markdown]
# แนะนำให้ใช้การระบุชื่อไฟล์ เนื่องจากในโปรแกรมออนไลน์มีการใช้การระบุตำแหน่งข้อมูลเป็นของตัวเอง แยกกับไฟล์ที่อยู่บนคอมพิวเตอร์ดังนั้นจะมีขั้นตอนที่ใช้งานต่างกัน

# %% [markdown]
# ดังนั้นการทำงานกับไฟล์ต่างๆ บนโปรแกรมออนไลน์จะต้องทำการอัพโหลดไฟล์ที่ต้องการไปยังโฟลเดอร์ชั่วคราวที่ถูกสร้างขึ้นตอนที่เข้าใช้งานตัวโปรแกรมออนไลน์

# %% [markdown]
# ### • ระบุชื่อไฟล์

# %%
name = "North.xlsx"
name
# Out:
# 'North.xlsx'

# %% [markdown]
# ## การเพิ่มไฟล์ไปยังโฟลเดอร์ปัจจุบัน

# %% [markdown]
# เพื่อเตรียมไฟล์สำหรับการใช้งานด้วยการเรียกชื่อไฟล์ สามารถทำได้ทั้งโปรแกรมที่ติดตั้งบนคอมพิวเตอร์ และโปรแกรมออนไลน์

# %% [markdown]
# ### • ไปยังโฟลเดอร์ปัจจุบันของ Notebook

# %% [markdown]
# เข้าถึงโฟลเดอร์ปัจจุบันของไฟล์ Notebook ได้ที่ File >> Open...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### • นำไฟล์มายัง Folder ปัจจุบัน

# %% [markdown]
# ผ่านการ "Upload" ที่จะคัดลอกไฟล์ที่เลือกมาใส่ในโฟลเดอร์ปัจจุบัน

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### • เลือกไฟล์ที่ดาวน์โหลดมา และ "Upload"

# %% [markdown]
# เลือกไฟล์ Credentials และ "Upload" ซึ่งจริงๆ เป็นการคัดลอกข้อมูลมายังโฟลเดอร์ปัจจุบันนั่นเอง

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### • ไฟล์ดังกล่าวจะถูกสร้างขึ้นในโฟลเดอร์ปัจจุบัน

# %% [markdown]
# ดูที่อยู่โฟลเดอร์ปัจจุบันได้ที่ตำแหน่งของเส้นสีแดงได้เลย

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## การนำข้อมูล Excel มาทำงานด้วย pandas

# %% [markdown]
# จะนำข้อมูล Excel เข้ามาเป็นข้อมูลประเภท DataFrame ที่เป็นประเภท Object ที่ถูกสร้างขึ้นด้วย pandas สำหรับการจัดการข้อมูลแบบตาราง

# %% [markdown]
# ทำความเข้าใจข้อจำกัดของการเลือกใช้การระบุตำแหน่งไฟล์ และการเรียกชื่อไฟล์ และเลือกใช้อันใดอันหนึ่งได้เลย

# %% [markdown]
# ### • การเปิดไฟล์ ด้วยโปรแกรมบนคอมพิวเตอร์

# %% [markdown]
# ทำความเข้าใจข้อจำกัดของการเลือกใช้การระบุตำแหน่งไฟล์ และการเรียกชื่อไฟล์ และเลือกใช้อันใดอันหนึ่งได้เลย

# %%
name = 'North.xlsx'
table = pd.read_excel(name)
table
# Out:
#                    Product  Qtr1  Qtr2  Qtr3  Qtr4
# 0       Basil Leaf (Whole)  6778  6760  4568  7834
# 1      Celery Seed (Whole)  3634  6344  6423  2546
# 2            North Special   875  1452   254  2451
# 3              Catnip Leaf   854   364   474   743
# 4        Asafoetida Powder   654   634   326   754
# 5              Anise Seeds   534   423   521   625
# 6   Cardamom Seed (Ground)   422   642   642   624
# 7        Chamomile Flowers   356   634   632   743
# 8     Caraway Seed (Whole)   354   633   422   255
# 9    Cardamom Seed (Whole)   255   525   252   624
# 10        Bay Leaf (Whole)   233   532   525   652

# %% [markdown]
# ### • การเปิดไฟล์ ด้วยโปรแกรมออนไลน์

# %% [markdown]
# การใช้โปรแกรมออนไลน์หมายถึงในบางครั้งเราจะมีเครื่องมือที่ต้องการไม่ครบ ซึ่งหนึ่งในเครื่องมือที่อาจขาดหายไปได้ นั่นคือเครื่องมือที่ใช้เปิดไฟล์ Excel ซึ่งสำหรับตัวออนไลน์เราจะใช้เครื่องมือที่ชื่อว่า openpyxl ที่ทำการติดตั้งเมื่อตอนต้นบทเรียนมาใช้เปิดไฟล์ ซึ่งต่างจากการเปิดไฟล์ด้วยโปรแกรมที่ติดตั้งบนเครื่องที่ Anaconda จะทำการติดตั้งเครื่องมือการเปิดให้เราแล้ว

# %% [markdown]
# การใช้งาน openpyxl ที่ติดตั้งแล้วข้างบน เพื่อเปิดไฟล์ Excel ใช้ผ่านการระบุผ่าน parameter ที่ชื่อว่า engine= โดยระบุ 'openpyxl' เป็น string ตามตัวอย่างด้านล่าง

# %%
name = 'North.xlsx'
table = pd.read_excel(name,engine='openpyxl')
table
# Out:
#                    Product  Qtr1  Qtr2  Qtr3  Qtr4
# 0       Basil Leaf (Whole)  6778  6760  4568  7834
# 1      Celery Seed (Whole)  3634  6344  6423  2546
# 2            North Special   875  1452   254  2451
# 3              Catnip Leaf   854   364   474   743
# 4        Asafoetida Powder   654   634   326   754
# 5              Anise Seeds   534   423   521   625
# 6   Cardamom Seed (Ground)   422   642   642   624
# 7        Chamomile Flowers   356   634   632   743
# 8     Caraway Seed (Whole)   354   633   422   255
# 9    Cardamom Seed (Whole)   255   525   252   624
# 10        Bay Leaf (Whole)   233   532   525   652

# %% [markdown]
# ## การเลือกเปิด sheet ที่ต้องการ

# %% [markdown]
# ถ้าต้องการเปิด sheet ที่เฉพาะเจาจะให้ใช้ parameter ที่ชื่อว่า sheet_name= และระบุชื่อชีทที่ต้องการเป็น string

# %%
table = pd.read_excel('North.xlsx',engine='openpyxl', sheet_name='North')
table
# Out:
#                    Product  Qtr1  Qtr2  Qtr3  Qtr4
# 0       Basil Leaf (Whole)  6778  6760  4568  7834
# 1      Celery Seed (Whole)  3634  6344  6423  2546
# 2            North Special   875  1452   254  2451
# 3              Catnip Leaf   854   364   474   743
# 4        Asafoetida Powder   654   634   326   754
# 5              Anise Seeds   534   423   521   625
# 6   Cardamom Seed (Ground)   422   642   642   624
# 7        Chamomile Flowers   356   634   632   743
# 8     Caraway Seed (Whole)   354   633   422   255
# 9    Cardamom Seed (Whole)   255   525   252   624
# 10        Bay Leaf (Whole)   233   532   525   652

# %% [markdown]
# # เสร็จสิ้นการเปิดไฟล์ Excel

# %% [markdown]
# ## [แจ้งปัญหาการใช้งาน คำติชม](http://m.me/ultimatepython)

# %% [markdown]
# ![%E0%B8%9B%E0%B8%81%E0%B8%9A%E0%B8%97%E0%B9%80%E0%B8%A3%E0%B8%B5%E0%B8%A2%E0%B8%99.png](attachment:%E0%B8%9B%E0%B8%81%E0%B8%9A%E0%B8%97%E0%B9%80%E0%B8%A3%E0%B8%B5%E0%B8%A2%E0%B8%99.png)
